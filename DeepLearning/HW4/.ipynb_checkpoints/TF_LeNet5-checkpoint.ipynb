# %%
import tensorflow as tf

print("Num GPUs Available", len(tf.config.experimental.list_physical_devices("GPU")))
# Out:
# Num GPUs Available 1

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17976740026512121724
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1440405915
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15866560173414700018
# physical_device_desc: "device: 0, name: GeForce 940MX, pci bus id: 0000:01:00.0, compute capability: 5.0"
# ]

# %%
import pathlib
AC_Dataset_Path="C:/Users/rathe/Desktop/Dataset/images/images/"
Dataset_Path = "C:/Users/USER/Desktop/Projects/Github_Repo/AI/DeepLearning/__HW1_DATA/images/"
data_dir = pathlib.Path(Dataset_Path)

# %%
image_count = len(list(data_dir.glob("*/*.jpeg")))
print(image_count)
# Out:
# 64225

# %%
import PIL.Image

black_dogs = list(data_dir.glob("n02111277/*"))
PIL.Image.open(str(black_dogs[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=343x256 at 0x1F954B6E888>

# %% [markdown]
# # Load useing Keras Preprocessing

# %%
import tensorflow as tf

# %%
batch_size = 50
img_height = 100
img_width  = 100

# %%
import numpy as np
img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.01)
#mean = np.array([123.68, 116.779, 103.939], dtype="float32")
#img_gen.mean = mean

train_generator = img_gen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

validation_generator = img_gen.flow_from_directory(
    data_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation') # set as validation data

# Wrap the generator with tf.data
#ds = tf.data.Dataset.from_generator(
#    lambda: img_gen.flow_from_directory(data_dir,
#            class_mode="categorical",
#            target_size=(30, 30),
#            color_mode="rgb",
#            batch_size = 50,
#            shuffle=True),
#    output_types=(tf.float32, tf.float32),
#    output_shapes = ([None,30,30,3],[None,50])
#)

#ds
# Out:
# Found 63584 images belonging to 50 classes.
# Found 641 images belonging to 50 classes.

# %% [markdown]
# # Visualize the data

# %%
from imutils import paths
total_data = len(list(paths.list_images(data_dir)))
total_data
# Out:
# 64225

# %%
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import layers

# Lenet5 Version

num_classes = 50

model = tf.keras.Sequential([
    layers.Conv2D(6, 3, input_shape=(100, 100, 3) ,activation="relu"),
    layers.MaxPooling2D(),
    layers.Conv2D(16, 3, activation="relu"),
    layers.MaxPooling2D(),
    layers.Conv2D(120, 6, activation="relu"),
    layers.Flatten(),
    layers.Dense(84, activation="relu"),
    layers.Dense(num_classes, activation="softmax"),
])

print(model.summary())

model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.001), metrics=['acc'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 98, 98, 6)         168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 49, 49, 6)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 47, 47, 16)        880
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 23, 23, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 18, 18, 120)       69240
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 38880)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 84)                3266004
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                4250
# =================================================================
# Total params: 3,340,542
# Trainable params: 3,340,542
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit_generator(train_generator, steps_per_epoch=63584//50, epochs=10, verbose=1, validation_data=validation_generator, validation_steps=641//50)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1271 steps, validate for 12 steps
# Epoch 1/10
#  438/1271 [=========>....................] - ETA: 2:14 - loss: 3.6778 - acc: 0.0750

# %%
import matplotlib.pyplot as plt

def plot_accuracy(history, miny=None):
    acc = history.history['acc']
    #test_acc = history.history['val_acc']
    epochs = range(len(acc))
    plt.plot(epochs, acc, c = "b", label='train_acc')
    #plt.plot(epochs, test_acc, c = "r" ,label='val_acc')
    plt.legend(loc="upper left")

    plt.title('accuracy') 
    plt.figure()
    plt.show()
    
plot_accuracy(history)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-4fbcf6298f4b> in <module>
#      13     plt.show()
#      14
# ---> 15 plot_accuracy(model)
#
# <ipython-input-25-4fbcf6298f4b> in plot_accuracy(history, miny)
#       2
#       3 def plot_accuracy(history, miny=None):
# ----> 4     acc = history.history['acc']
#       5     #test_acc = history.history['val_acc']
#       6     epochs = range(len(acc))
#
# TypeError: 'History' object is not subscriptable
